# %%
import pandas as pd

# %%
audio = pd.read_csv('../Feature Extraction/audio_sarcasm_dataset.csv')
audio.columns
# Out:
# Index(['Unnamed: 0', 'sarcasm_label', 'emotion_label', 'sentiment_label', 'id',
#        'sentence_level_similarity_emotion', 'sentence_level_similarity_word',
#        'exclamation', 'AUDIO_1', 'AUDIO_2', 'AUDIO_3', 'AUDIO_4', 'AUDIO_5',
#        'AUDIO_6', 'AUDIO_7', 'AUDIO_8'],
#       dtype='object')

# %%
# Assuming df is your DataFrame
audio.rename(columns={
    'AUDIO_1': 'PCA_MFCC_1',
    'AUDIO_2': 'PCA_MFCC_2',
    'AUDIO_3': 'PCA_MFCC_3',
    'AUDIO_4': 'PCA_MFCC_4',
    'AUDIO_5': 'PCA_MFCC_5',
    'AUDIO_6': 'PCA_MFCC_6',
    'AUDIO_7': 'PCA_MFCC_7',
    'AUDIO_8': 'PCA_MFCC_8'
}, inplace=True)

# %%
audio
# Out:
#      Unnamed: 0  sarcasm_label emotion_label  sentiment_label   id  \
# 0             0              0         anger                0    1
# 1             1              0         anger                0    2
# 2             2              0         anger                0    3
# 3             3              0         anger                0    4
# 4             4              0         anger                0    5
# ..          ...            ...           ...              ...  ...
# 254         419              0      surprise                0  420
# 255         421              0      surprise                0  422
# 256         422              0      surprise                0  423
# 257         425              0      surprise                0  426
# 258         427              0      surprise                0  428
#
#      sentence_level_similarity_emotion  sentence_level_similarity_word  \
# 0                             0.000000                        0.000000
# 1                             0.000000                        0.000000
# 2                             0.439865                        0.913640
# 3                             0.009295                        0.920026
# 4                             0.000000                        0.000000
# ..                                 ...                             ...
# 254                           0.000000                        0.000000
# 255                          -0.688249                        0.938817
# 256                           0.000000                        0.000000
# 257                           0.779693                        0.706350
# 258                           0.000000                        0.000000
#
#      exclamation  PCA_MFCC_1  PCA_MFCC_2  PCA_MFCC_3  PCA_MFCC_4  PCA_MFCC_5  \
# 0              0   -2.276627    1.194254    1.073762   -0.120506   -0.308371
# 1              0   -0.920419   -0.245156    1.557069   -0.234828    0.540239
# 2              0   -1.511857   -0.118752    0.132647   -0.888176    0.340909
# 3              1   -1.032136    1.556911    0.385882   -0.252339   -0.164264
# 4              1    0.139397   -0.984472    0.358380    0.581564   -0.502099
# ..           ...         ...         ...         ...         ...         ...
# 254            0   -1.219419    0.458677    2.047222    0.538345    1.131656
# 255            0   -0.195316   -0.250842   -0.458744   -0.920555   -0.709591
# 256            1    2.020319    2.749040   -0.155967   -0.044834    0.379603
# 257            1   -1.857867    1.587987   -0.524588   -0.655474   -1.968691
# 258            0   -2.124620   -0.969605    2.702946   -0.300067    0.464363
#
#      PCA_MFCC_6  PCA_MFCC_7  PCA_MFCC_8
# 0      0.027054   -0.521969   -1.144353
# 1      1.073943    0.077584    1.199006
# 2     -1.137311    0.961322    1.532151
# 3     -0.412079   -0.039664   -0.533009
# 4     -0.111040    0.787407    0.286733
# ..          ...         ...         ...
# 254   -0.402536   -0.563440    0.952709
# 255   -0.709534   -0.109214   -0.370972
# 256    0.893045   -0.124065    1.150491
# 257    0.052819   -1.107251    0.223600
# 258    0.705530   -0.208636    0.481005
#
# [259 rows x 16 columns]

# %%
text = pd.read_csv('../datasets/sarcasm_dataset.csv')

# Assuming df is your DataFrame
text.rename(columns={
    f'PCA_{i}': f'PCA_W2V_{i}' for i in range(1, 61)  # This creates mappings from TEXT_1 to TEXT_50
}, inplace=True)

text
# Out:
#      Unnamed: 0  sarcasm_label emotion_label  sentiment_label   id  \
# 0             0              0         anger                0    1
# 1             1              0         anger                0    2
# 2             2              0         anger                0    3
# 3             3              0         anger                0    4
# 4             4              0         anger                0    5
# ..          ...            ...           ...              ...  ...
# 252         419              0      surprise                0  420
# 253         421              0      surprise                0  422
# 254         422              0      surprise                0  423
# 255         425              0      surprise                0  426
# 256         427              0      surprise                0  428
#
#      sentence_level_similarity_emotion  sentence_level_similarity_word  \
# 0                             0.000000                        0.000000
# 1                             0.000000                        0.000000
# 2                             0.439865                        0.913640
# 3                             0.009295                        0.920026
# 4                             0.000000                        0.000000
# ..                                 ...                             ...
# 252                           0.000000                        0.000000
# 253                          -0.688249                        0.938817
# 254                           0.000000                        0.000000
# 255                           0.779693                        0.706350
# 256                           0.000000                        0.000000
#
#      exclamation  PCA_W2V_1  PCA_W2V_2  ...    mfccs_4    mfccs_5    mfccs_6  \
# 0              0  -4.560275   9.361766  ...  -0.696655  -8.942310  -9.985609
# 1              0   1.882024 -10.278302  ...  30.882395  -4.019680   1.883116
# 2              0   3.933007  -1.102636  ...  32.325928   5.849225 -11.916834
# 3              1   0.994384   1.081702  ...   0.763123  -5.845510  -2.330540
# 4              1   3.942157  -0.354175  ...  25.155962  -0.180788   5.027461
# ..           ...        ...        ...  ...        ...        ...        ...
# 252            0   6.692438  -2.622186  ...  24.404045  -9.279648 -12.074842
# 253            0   4.782721  -6.644729  ...  11.167129   7.023430  -2.150115
# 254            1   1.147711  12.323190  ...  26.562054  -3.516582  17.017010
# 255            1   1.075184  -1.541483  ...   6.051051 -21.950787  -9.932963
# 256            0   5.679678  -1.659085  ...  22.917297  -7.171116  -4.149225
#
#        mfccs_7   mfccs_8    mfccs_9   mfccs_10  mfccs_11   mfccs_12   mfccs_13
# 0    -6.722595 -6.088647 -12.381520  -7.555905 -1.583094  -0.908265   0.076475
# 1   -17.866735 -3.908888  -3.751518 -10.702564  4.395910 -10.536695  -3.936949
# 2   -12.052676 -5.394704  -2.760267 -19.729319 -6.801490   1.375306  -4.763419
# 3    -7.007518 -4.011292  -3.346781  -7.034707 -0.251097   0.279195  -0.902673
# 4    -7.410805 -8.471725  -2.567751  -6.176376 -2.000684  -5.672810 -10.509291
# ..         ...       ...        ...        ...       ...        ...        ...
# 252 -14.694478 -3.689736   0.698756  -7.965335  4.698254  -7.224542  -4.550307
# 253  -6.244311 -4.573157  -4.578991  -9.186458 -3.376259  -3.309016  -5.646399
# 254  -6.967735  8.787129   4.810155   3.234943 -0.917468   2.263414   3.694980
# 255 -10.389060 -2.835590  -7.235012  -9.984515 -1.476463  -0.727933   0.317069
# 256 -13.418255 -0.421805 -14.986924 -13.853695 -1.475043  -8.827969  -5.650708
#
# [257 rows x 86 columns]

# %%
text = text[['id', 'PCA_W2V_1', 'PCA_W2V_2', 'PCA_W2V_3', 'PCA_W2V_4',
       'PCA_W2V_5', 'PCA_W2V_6', 'PCA_W2V_7', 'PCA_W2V_8', 'PCA_W2V_9',
       'PCA_W2V_10', 'PCA_W2V_11', 'PCA_W2V_12', 'PCA_W2V_13', 'PCA_W2V_14',
       'PCA_W2V_15', 'PCA_W2V_16', 'PCA_W2V_17', 'PCA_W2V_18', 'PCA_W2V_19',
       'PCA_W2V_20', 'PCA_W2V_21', 'PCA_W2V_22', 'PCA_W2V_23', 'PCA_W2V_24',
       'PCA_W2V_25', 'PCA_W2V_26', 'PCA_W2V_27', 'PCA_W2V_28', 'PCA_W2V_29',
       'PCA_W2V_30', 'PCA_W2V_31', 'PCA_W2V_32', 'PCA_W2V_33', 'PCA_W2V_34',
       'PCA_W2V_35', 'PCA_W2V_36', 'PCA_W2V_37', 'PCA_W2V_38', 'PCA_W2V_39',
       'PCA_W2V_40', 'PCA_W2V_41', 'PCA_W2V_42', 'PCA_W2V_43', 'PCA_W2V_44',
       'PCA_W2V_45', 'PCA_W2V_46', 'PCA_W2V_47', 'PCA_W2V_48', 'PCA_W2V_49',
       'PCA_W2V_50', 'PCA_W2V_51', 'PCA_W2V_52', 'PCA_W2V_53', 'PCA_W2V_54', 'PCA_W2V_55',
       'PCA_W2V_56', 'PCA_W2V_57', 'PCA_W2V_58', 'PCA_W2V_59', 'PCA_W2V_60', 'spectral_centroid',
       'spectral_bandwidth', 'pitch']]

# %%
merged_df = audio.merge(text, on='id', suffixes=('_audio', '_text'))

# Filter out the _text columns that have a corresponding _audio column
for col in merged_df.columns:
    if col.endswith('_text'):
        audio_col = col.replace('_text', '_audio')
        if audio_col in merged_df.columns:
            merged_df.drop(col, axis=1, inplace=True)  # Drop the text column if the audio column exists
        else:
            # Rename back to original if no corresponding audio column exists
            merged_df.rename(columns={col: col.replace('_text', '')}, inplace=True)

# Optionally, rename columns to remove the suffix from audio columns where no overlap occurred
for col in merged_df.columns:
    if col.endswith('_audio'):
        merged_df.rename(columns={col: col.replace('_audio', '')}, inplace=True)

# Now merged_df contains all columns from 'audio' and only non-overlapping columns from 'text'

# %%
sum(merged_df.sarcasm_label)
# Out:
# 69

# %%
merged_df.to_csv('sarcasm_final.csv')

# %%
merged_df = audio.merge(text, on='id', suffixes=('_audio', '_text'))

# Filter out the _text columns that have a corresponding _audio column
for col in merged_df.columns:
    if col.endswith('_text'):
        audio_col = col.replace('_text', '_audio')
        if audio_col in merged_df.columns:
            merged_df.drop(col, axis=1, inplace=True)  # Drop the text column if the audio column exists
        else:
            # Rename back to original if no corresponding audio column exists
            merged_df.rename(columns={col: col.replace('_text', '')}, inplace=True)

# Optionally, rename columns to remove the suffix from audio columns where no overlap occurred
for col in merged_df.columns:
    if col.endswith('_audio'):
        merged_df.rename(columns={col: col.replace('_audio', '')}, inplace=True)

# Now merged_df contains all columns from 'audio' and only non-overlapping columns from 'text'

# %%
merged_df.columns
# Out:
# Index(['Unnamed: 0', 'sarcasm_label', 'emotion_label', 'sentiment_label', 'id',
#        'sentence_level_similarity_emotion', 'sentence_level_similarity_word',
#        'exclamation', 'PCA_MFCC_1', 'PCA_MFCC_2', 'PCA_MFCC_3', 'PCA_MFCC_4',
#        'PCA_MFCC_5', 'PCA_MFCC_6', 'PCA_MFCC_7', 'PCA_MFCC_8', 'PCA_W2V_1',
#        'PCA_W2V_2', 'PCA_W2V_3', 'PCA_W2V_4', 'PCA_W2V_5', 'PCA_W2V_6',
#        'PCA_W2V_7', 'PCA_W2V_8', 'PCA_W2V_9', 'PCA_W2V_10', 'PCA_W2V_11',
#        'PCA_W2V_12', 'PCA_W2V_13', 'PCA_W2V_14', 'PCA_W2V_15', 'PCA_W2V_16',
#        'PCA_W2V_17', 'PCA_W2V_18', 'PCA_W2V_19', 'PCA_W2V_20', 'PCA_W2V_21',
#        'PCA_W2V_22', 'PCA_W2V_23', 'PCA_W2V_24', 'PCA_W2V_25', 'PCA_W2V_26',
#        'PCA_W2V_27', 'PCA_W2V_28', 'PCA_W2V_29', 'PCA_W2V_30', 'PCA_W2V_31',
#        'PCA_W2V_32', 'PCA_W2V_33', 'PCA_W2V_34', 'PCA_W2V_35', 'PCA_W2V_36',
#        'PCA_W2V_37', 'PCA_W2V_38', 'PCA_W2V_39', 'PCA_W2V_40', 'PCA_W2V_41',
#        'PCA_W2V_42', 'PCA_W2V_43', 'PCA_W2V_44', 'PCA_W2V_45', 'PCA_W2V_46',
#        'PCA_W2V_47', 'PCA_W2V_48', 'PCA_W2V_49', 'PCA_W2V_50', 'PCA_51',
#        'PCA_52', 'PCA_53', 'PCA_54', 'PCA_55', 'PCA_56', 'PCA_57', 'PCA_58',
#        'PCA_59', 'PCA_60', 'spectral_centroid', 'spectral_bandwidth', 'pitch'],
#       dtype='object')

# %%
ref = pd.read_csv('../datasets/sarcasm_final.csv')
set(ref.columns) - set(merged_df.columns)
# Out:
# {'PCA_W2V_51',
#  'PCA_W2V_52',
#  'PCA_W2V_53',
#  'PCA_W2V_54',
#  'PCA_W2V_55',
#  'PCA_W2V_56',
#  'PCA_W2V_57',
#  'PCA_W2V_58',
#  'PCA_W2V_59',
#  'PCA_W2V_60',
#  'energy',
#  'loudness',
#  'mfccs_1',
#  'mfccs_10',
#  'mfccs_11',
#  'mfccs_12',
#  'mfccs_13',
#  'mfccs_2',
#  'mfccs_3',
#  'mfccs_4',
#  'mfccs_5',
#  'mfccs_6',
#  'mfccs_7',
#  'mfccs_8',
#  'mfccs_9'}
