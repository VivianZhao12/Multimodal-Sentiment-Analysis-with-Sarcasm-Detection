# %% [markdown]
# # Audio Feature Extraction

# %%
! pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: numpy in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from noisereduce) (1.24.4)
# Requirement already satisfied: scipy in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from noisereduce) (1.10.1)
# Requirement already satisfied: joblib in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from noisereduce) (1.2.0)
# Requirement already satisfied: tqdm in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from noisereduce) (4.62.3)
# Requirement already satisfied: matplotlib in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from noisereduce) (3.7.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (8.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (4.54.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from matplotlib->noisereduce) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->noisereduce) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

import os
from scipy.io import wavfile
from scipy.io import wavfile as wav
import noisereduce as nr
import soundfile as sf

# %%
df = pd.read_csv('full_id.csv')

# %%
# Sample sound file path
sample_file = 'original_audio_data/1.wav'

# Load audio file
sample_data, sample_sample_rate = librosa.load(sample_file)

# Plot the waveform
plt.figure(figsize=(14, 5))
librosa.display.waveshow(sample_data, sr=sample_sample_rate)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# Play the audio
ipd.Audio(sample_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav_folder = 'original_audio_data'

# Lists to store filenames by channel type
mono_files = []
stereo_files = []
multi_channel_files = []

# Check each .wav file in the directory
for file in os.listdir(wav_folder):
    if file.endswith('.wav'):
        file_path = os.path.join(wav_folder, file)
        
        try:
            sample_rate, audio_data = wavfile.read(file_path)
            
            # Check if mono (1 channel)
            if audio_data.ndim == 1 or (audio_data.ndim == 2 and audio_data.shape[1] == 1):
                mono_files.append(file)
            
            # Check if stereo (2 channels)
            elif audio_data.ndim == 2 and audio_data.shape[1] == 2:
                stereo_files.append(file)
            
            # Check if multi-channel (3 or more channels)
            elif audio_data.ndim == 2 and audio_data.shape[1] >= 3:
                multi_channel_files.append(file)
                
        except Exception as e:
            print(f"Error reading {file}: {e}")

# Print the counts and store file lists
print("\nSummary:")
print(f"Mono files (1 channel): {len(mono_files)}")
print(f"Stereo files (2 channels): {len(stereo_files)}")
print(f"Multi-channel files (3 or more channels): {len(multi_channel_files)}")
# Out:
# Summary:
# Mono files (1 channel): 179
# Stereo files (2 channels): 250
# Multi-channel files (3 or more channels): 0

# %%
### Lets read with scipy
mono_wave_sr, mono_wave_audio = wav.read('original_audio_data/' + mono_files[0]) 

# Original audio with 1 channels 
plt.figure(figsize=(12, 4))
plt.plot(mono_wave_audio)

# %%
stereo_wave_sr, stereo_wave_audio = wav.read('original_audio_data/' + stereo_files[0]) 

# Original audio with 2 channels 
plt.figure(figsize=(12, 4))
plt.plot(stereo_wave_audio)
# Out:
# [<matplotlib.lines.Line2D at 0x283a0e710>,
#  <matplotlib.lines.Line2D at 0x16feb0d50>]

# %% [markdown]
# ## Noise Reduction

# %%
sample_data_denoised = nr.reduce_noise(y=sample_data, sr=sample_sample_rate)

# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display as ipd

# Assuming 'sample_file_denoised' and 'data' are already loaded, and 'sample_rate' is defined

plt.figure(figsize=(14, 5))

# Plot the original waveform
plt.subplot(1, 2, 1)
librosa.display.waveshow(sample_data, sr=sample_sample_rate)
plt.title('Waveform (Original)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

# Plot the denoised waveform
plt.subplot(1, 2, 2)
librosa.display.waveshow(sample_data_denoised, sr=sample_sample_rate)
plt.title('Waveform (Denoised)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# Play both audio files
print("Original Audio:")
ipd.display(ipd.Audio(sample_data, rate=sample_sample_rate))  # Play original audio

print("Denoised Audio:")
ipd.display(ipd.Audio(sample_data_denoised, rate=sample_sample_rate))  # Play denoised audio
# Out:
# Original Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Denoised Audio:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Define input and output folders
input_folder = 'original_audio_data'  # Replace with your actual input folder path
output_folder = 'reduced_audio_data'  # Replace with your actual output folder path

# Ensure output folder exists
os.makedirs(output_folder, exist_ok=True)

# Process each .wav file in the input folder
for file_name in os.listdir(input_folder):
    if file_name.endswith('.wav'):
        input_path = os.path.join(input_folder, file_name)
        output_path = os.path.join(output_folder, file_name)

        try:
            # Load audio file
            data, sample_rate = librosa.load(input_path, sr=None)

            # Apply noise reduction
            reduced_noise = nr.reduce_noise(y=data, sr=sample_rate)

            # Save the noise-reduced audio
            sf.write(output_path, reduced_noise, sample_rate)

            print(f"Processed and saved: {output_path}")
        except Exception as e:
            print(f"Error processing {file_name}: {e}")
# Out:
# Processed and saved: reduced_audio_data/249.wav
# Processed and saved: reduced_audio_data/275.wav
# Processed and saved: reduced_audio_data/261.wav
# Processed and saved: reduced_audio_data/16.wav
# Processed and saved: reduced_audio_data/103.wav
# Processed and saved: reduced_audio_data/117.wav
# Processed and saved: reduced_audio_data/329.wav
# Processed and saved: reduced_audio_data/301.wav
# Processed and saved: reduced_audio_data/315.wav
# Processed and saved: reduced_audio_data/314.wav
# Processed and saved: reduced_audio_data/300.wav
# Processed and saved: reduced_audio_data/328.wav
# Processed and saved: reduced_audio_data/116.wav
# Processed and saved: reduced_audio_data/102.wav
# Processed and saved: reduced_audio_data/17.wav
# Processed and saved: reduced_audio_data/260.wav
# Processed and saved: reduced_audio_data/274.wav
# Processed and saved: reduced_audio_data/248.wav
# Processed and saved: reduced_audio_data/289.wav
# Processed and saved: reduced_audio_data/262.wav
# Processed and saved: reduced_audio_data/276.wav
# Processed and saved: reduced_audio_data/15.wav
# Processed and saved: reduced_audio_data/29.wav
# Processed and saved: reduced_audio_data/128.wav
# Processed and saved: reduced_audio_data/114.wav
# Processed and saved: reduced_audio_data/100.wav
# Processed and saved: reduced_audio_data/316.wav
# Processed and saved: reduced_audio_data/302.wav
# Processed and saved: reduced_audio_data/303.wav
# Processed and saved: reduced_audio_data/317.wav
# Processed and saved: reduced_audio_data/101.wav
# Processed and saved: reduced_audio_data/115.wav
# Processed and saved: reduced_audio_data/129.wav
# Processed and saved: reduced_audio_data/28.wav
# Processed and saved: reduced_audio_data/14.wav
# Processed and saved: reduced_audio_data/277.wav
# Processed and saved: reduced_audio_data/263.wav
# Processed and saved: reduced_audio_data/288.wav
# Processed and saved: reduced_audio_data/298.wav
# Processed and saved: reduced_audio_data/267.wav
# Processed and saved: reduced_audio_data/273.wav
# Processed and saved: reduced_audio_data/38.wav
# Processed and saved: reduced_audio_data/10.wav
# Processed and saved: reduced_audio_data/111.wav
# Processed and saved: reduced_audio_data/105.wav
# Processed and saved: reduced_audio_data/139.wav
# Processed and saved: reduced_audio_data/313.wav
# Processed and saved: reduced_audio_data/307.wav
# Processed and saved: reduced_audio_data/306.wav
# Processed and saved: reduced_audio_data/312.wav
# Processed and saved: reduced_audio_data/138.wav
# Processed and saved: reduced_audio_data/104.wav
# Processed and saved: reduced_audio_data/110.wav
# Processed and saved: reduced_audio_data/11.wav
# Processed and saved: reduced_audio_data/39.wav
# Processed and saved: reduced_audio_data/272.wav
# Processed and saved: reduced_audio_data/266.wav
# Processed and saved: reduced_audio_data/299.wav
# Processed and saved: reduced_audio_data/270.wav
# Processed and saved: reduced_audio_data/264.wav
# Processed and saved: reduced_audio_data/258.wav
# Processed and saved: reduced_audio_data/13.wav
# Processed and saved: reduced_audio_data/106.wav
# Processed and saved: reduced_audio_data/112.wav
# Processed and saved: reduced_audio_data/304.wav
# Processed and saved: reduced_audio_data/310.wav
# Processed and saved: reduced_audio_data/338.wav
# Processed and saved: reduced_audio_data/339.wav
# Processed and saved: reduced_audio_data/311.wav
# Processed and saved: reduced_audio_data/305.wav
# Processed and saved: reduced_audio_data/113.wav
# Processed and saved: reduced_audio_data/107.wav
# Processed and saved: reduced_audio_data/12.wav
# Processed and saved: reduced_audio_data/259.wav
# Processed and saved: reduced_audio_data/265.wav
# Processed and saved: reduced_audio_data/271.wav
# Processed and saved: reduced_audio_data/216.wav
# Processed and saved: reduced_audio_data/202.wav
# Processed and saved: reduced_audio_data/61.wav
# Processed and saved: reduced_audio_data/75.wav
# Processed and saved: reduced_audio_data/49.wav
# Processed and saved: reduced_audio_data/148.wav
# Processed and saved: reduced_audio_data/160.wav
# Processed and saved: reduced_audio_data/174.wav
# Processed and saved: reduced_audio_data/389.wav
# Processed and saved: reduced_audio_data/404.wav
# Processed and saved: reduced_audio_data/362.wav
# Processed and saved: reduced_audio_data/376.wav
# Processed and saved: reduced_audio_data/410.wav
# Processed and saved: reduced_audio_data/377.wav
# Processed and saved: reduced_audio_data/411.wav
# Processed and saved: reduced_audio_data/405.wav
# Processed and saved: reduced_audio_data/363.wav
# Processed and saved: reduced_audio_data/388.wav
# Processed and saved: reduced_audio_data/175.wav
# Processed and saved: reduced_audio_data/161.wav
# Processed and saved: reduced_audio_data/149.wav
# Processed and saved: reduced_audio_data/48.wav
# Processed and saved: reduced_audio_data/74.wav
# Processed and saved: reduced_audio_data/60.wav
# Processed and saved: reduced_audio_data/203.wav
# Processed and saved: reduced_audio_data/217.wav
# Processed and saved: reduced_audio_data/229.wav
# Processed and saved: reduced_audio_data/201.wav
# Processed and saved: reduced_audio_data/215.wav
# Processed and saved: reduced_audio_data/188.wav
# Processed and saved: reduced_audio_data/76.wav
# Processed and saved: reduced_audio_data/62.wav
# Processed and saved: reduced_audio_data/177.wav
# Processed and saved: reduced_audio_data/89.wav
# Processed and saved: reduced_audio_data/163.wav
# Processed and saved: reduced_audio_data/349.wav
# Processed and saved: reduced_audio_data/413.wav
# Processed and saved: reduced_audio_data/375.wav
# Processed and saved: reduced_audio_data/361.wav
# Processed and saved: reduced_audio_data/407.wav
# Processed and saved: reduced_audio_data/360.wav
# Processed and saved: reduced_audio_data/406.wav
# Processed and saved: reduced_audio_data/412.wav
# Processed and saved: reduced_audio_data/374.wav
# Processed and saved: reduced_audio_data/348.wav
# Processed and saved: reduced_audio_data/162.wav
# Processed and saved: reduced_audio_data/176.wav
# Processed and saved: reduced_audio_data/88.wav
# Processed and saved: reduced_audio_data/63.wav
# Processed and saved: reduced_audio_data/189.wav
# Processed and saved: reduced_audio_data/77.wav
# Processed and saved: reduced_audio_data/214.wav
# Processed and saved: reduced_audio_data/200.wav
# Processed and saved: reduced_audio_data/228.wav
# Processed and saved: reduced_audio_data/204.wav
# Processed and saved: reduced_audio_data/210.wav
# Processed and saved: reduced_audio_data/238.wav
# Processed and saved: reduced_audio_data/9.wav
# Processed and saved: reduced_audio_data/73.wav
# Processed and saved: reduced_audio_data/199.wav
# Processed and saved: reduced_audio_data/67.wav
# Processed and saved: reduced_audio_data/172.wav
# Processed and saved: reduced_audio_data/166.wav
# Processed and saved: reduced_audio_data/98.wav
# Processed and saved: reduced_audio_data/370.wav
# Processed and saved: reduced_audio_data/416.wav
# Processed and saved: reduced_audio_data/402.wav
# Processed and saved: reduced_audio_data/364.wav
# Processed and saved: reduced_audio_data/358.wav
# Processed and saved: reduced_audio_data/359.wav
# Processed and saved: reduced_audio_data/403.wav
# Processed and saved: reduced_audio_data/365.wav
# Processed and saved: reduced_audio_data/371.wav
# Processed and saved: reduced_audio_data/417.wav
# Processed and saved: reduced_audio_data/167.wav
# Processed and saved: reduced_audio_data/99.wav
# Processed and saved: reduced_audio_data/173.wav
# Processed and saved: reduced_audio_data/198.wav
# Processed and saved: reduced_audio_data/66.wav
# Processed and saved: reduced_audio_data/72.wav
# Processed and saved: reduced_audio_data/8.wav
# Processed and saved: reduced_audio_data/239.wav
# Processed and saved: reduced_audio_data/211.wav
# Processed and saved: reduced_audio_data/205.wav
# Processed and saved: reduced_audio_data/213.wav
# Processed and saved: reduced_audio_data/207.wav
# Processed and saved: reduced_audio_data/58.wav
# Processed and saved: reduced_audio_data/64.wav
# Processed and saved: reduced_audio_data/70.wav
# Processed and saved: reduced_audio_data/165.wav
# Processed and saved: reduced_audio_data/171.wav
# Processed and saved: reduced_audio_data/159.wav
# Processed and saved: reduced_audio_data/398.wav
# Processed and saved: reduced_audio_data/367.wav
# Processed and saved: reduced_audio_data/401.wav
# Processed and saved: reduced_audio_data/415.wav
# Processed and saved: reduced_audio_data/373.wav
# Processed and saved: reduced_audio_data/429.wav
# Processed and saved: reduced_audio_data/428.wav
# Processed and saved: reduced_audio_data/414.wav
# Processed and saved: reduced_audio_data/372.wav
# Processed and saved: reduced_audio_data/366.wav
# Processed and saved: reduced_audio_data/400.wav
# Processed and saved: reduced_audio_data/399.wav
# Processed and saved: reduced_audio_data/158.wav
# Processed and saved: reduced_audio_data/170.wav
# Processed and saved: reduced_audio_data/164.wav
# Processed and saved: reduced_audio_data/71.wav
# Processed and saved: reduced_audio_data/65.wav
# Processed and saved: reduced_audio_data/59.wav
# Processed and saved: reduced_audio_data/206.wav
# Processed and saved: reduced_audio_data/212.wav
# Processed and saved: reduced_audio_data/237.wav
# Processed and saved: reduced_audio_data/223.wav
# Processed and saved: reduced_audio_data/40.wav
# Processed and saved: reduced_audio_data/54.wav
# Processed and saved: reduced_audio_data/6.wav
# Processed and saved: reduced_audio_data/182.wav
# Processed and saved: reduced_audio_data/68.wav
# Processed and saved: reduced_audio_data/196.wav
# Processed and saved: reduced_audio_data/83.wav
# Processed and saved: reduced_audio_data/97.wav
# Processed and saved: reduced_audio_data/169.wav
# Processed and saved: reduced_audio_data/141.wav
# Processed and saved: reduced_audio_data/155.wav
# Processed and saved: reduced_audio_data/380.wav
# Processed and saved: reduced_audio_data/394.wav
# Processed and saved: reduced_audio_data/419.wav
# Processed and saved: reduced_audio_data/425.wav
# Processed and saved: reduced_audio_data/343.wav
# Processed and saved: reduced_audio_data/357.wav
# Processed and saved: reduced_audio_data/356.wav
# Processed and saved: reduced_audio_data/424.wav
# Processed and saved: reduced_audio_data/342.wav
# Processed and saved: reduced_audio_data/418.wav
# Processed and saved: reduced_audio_data/395.wav
# Processed and saved: reduced_audio_data/381.wav
# Processed and saved: reduced_audio_data/154.wav
# Processed and saved: reduced_audio_data/140.wav
# Processed and saved: reduced_audio_data/96.wav
# Processed and saved: reduced_audio_data/168.wav
# Processed and saved: reduced_audio_data/82.wav
# Processed and saved: reduced_audio_data/69.wav
# Processed and saved: reduced_audio_data/197.wav
# Processed and saved: reduced_audio_data/183.wav
# Processed and saved: reduced_audio_data/55.wav
# Processed and saved: reduced_audio_data/7.wav
# Processed and saved: reduced_audio_data/41.wav
# Processed and saved: reduced_audio_data/222.wav
# Processed and saved: reduced_audio_data/236.wav
# Processed and saved: reduced_audio_data/208.wav
# Processed and saved: reduced_audio_data/220.wav
# Processed and saved: reduced_audio_data/234.wav
# Processed and saved: reduced_audio_data/5.wav
# Processed and saved: reduced_audio_data/57.wav
# Processed and saved: reduced_audio_data/43.wav
# Processed and saved: reduced_audio_data/195.wav
# Processed and saved: reduced_audio_data/181.wav
# Processed and saved: reduced_audio_data/94.wav
# Processed and saved: reduced_audio_data/80.wav
# Processed and saved: reduced_audio_data/156.wav
# Processed and saved: reduced_audio_data/142.wav
# Processed and saved: reduced_audio_data/397.wav
# Processed and saved: reduced_audio_data/383.wav
# Processed and saved: reduced_audio_data/368.wav
# Processed and saved: reduced_audio_data/354.wav
# Processed and saved: reduced_audio_data/340.wav
# Processed and saved: reduced_audio_data/426.wav
# Processed and saved: reduced_audio_data/341.wav
# Processed and saved: reduced_audio_data/427.wav
# Processed and saved: reduced_audio_data/355.wav
# Processed and saved: reduced_audio_data/369.wav
# Processed and saved: reduced_audio_data/382.wav
# Processed and saved: reduced_audio_data/396.wav
# Processed and saved: reduced_audio_data/143.wav
# Processed and saved: reduced_audio_data/157.wav
# Processed and saved: reduced_audio_data/81.wav
# Processed and saved: reduced_audio_data/95.wav
# Processed and saved: reduced_audio_data/180.wav
# Processed and saved: reduced_audio_data/194.wav
# Processed and saved: reduced_audio_data/42.wav
# Processed and saved: reduced_audio_data/4.wav
# Processed and saved: reduced_audio_data/56.wav
# Processed and saved: reduced_audio_data/235.wav
# Processed and saved: reduced_audio_data/221.wav
# Processed and saved: reduced_audio_data/209.wav
# Processed and saved: reduced_audio_data/225.wav
# Processed and saved: reduced_audio_data/231.wav
# Processed and saved: reduced_audio_data/219.wav
# Processed and saved: reduced_audio_data/190.wav
# Processed and saved: reduced_audio_data/184.wav
# Processed and saved: reduced_audio_data/52.wav
# Processed and saved: reduced_audio_data/46.wav
# Processed and saved: reduced_audio_data/153.wav
# Processed and saved: reduced_audio_data/147.wav
# Processed and saved: reduced_audio_data/91.wav
# Processed and saved: reduced_audio_data/85.wav
# Processed and saved: reduced_audio_data/392.wav
# Processed and saved: reduced_audio_data/386.wav
# Processed and saved: reduced_audio_data/351.wav
# Processed and saved: reduced_audio_data/423.wav
# Processed and saved: reduced_audio_data/345.wav
# Processed and saved: reduced_audio_data/379.wav
# Processed and saved: reduced_audio_data/378.wav
# Processed and saved: reduced_audio_data/422.wav
# Processed and saved: reduced_audio_data/344.wav
# Processed and saved: reduced_audio_data/350.wav
# Processed and saved: reduced_audio_data/387.wav
# Processed and saved: reduced_audio_data/393.wav
# Processed and saved: reduced_audio_data/84.wav
# Processed and saved: reduced_audio_data/90.wav
# Processed and saved: reduced_audio_data/146.wav
# Processed and saved: reduced_audio_data/152.wav
# Processed and saved: reduced_audio_data/47.wav
# Processed and saved: reduced_audio_data/53.wav
# Processed and saved: reduced_audio_data/1.wav
# Processed and saved: reduced_audio_data/185.wav
# Processed and saved: reduced_audio_data/191.wav
# Processed and saved: reduced_audio_data/218.wav
# Processed and saved: reduced_audio_data/230.wav
# Processed and saved: reduced_audio_data/224.wav
# Processed and saved: reduced_audio_data/232.wav
# Processed and saved: reduced_audio_data/226.wav
# Processed and saved: reduced_audio_data/79.wav
# Processed and saved: reduced_audio_data/187.wav
# Processed and saved: reduced_audio_data/193.wav
# Processed and saved: reduced_audio_data/45.wav
# Processed and saved: reduced_audio_data/3.wav
# Processed and saved: reduced_audio_data/51.wav
# Processed and saved: reduced_audio_data/144.wav
# Processed and saved: reduced_audio_data/150.wav
# Processed and saved: reduced_audio_data/86.wav
# Processed and saved: reduced_audio_data/178.wav
# Processed and saved: reduced_audio_data/92.wav
# Processed and saved: reduced_audio_data/385.wav
# Processed and saved: reduced_audio_data/391.wav
# Processed and saved: reduced_audio_data/346.wav
# Processed and saved: reduced_audio_data/420.wav
# Processed and saved: reduced_audio_data/352.wav
# Processed and saved: reduced_audio_data/408.wav
# Processed and saved: reduced_audio_data/409.wav
# Processed and saved: reduced_audio_data/353.wav
# Processed and saved: reduced_audio_data/347.wav
# Processed and saved: reduced_audio_data/421.wav
# Processed and saved: reduced_audio_data/390.wav
# Processed and saved: reduced_audio_data/384.wav
# Processed and saved: reduced_audio_data/93.wav
# Processed and saved: reduced_audio_data/87.wav
# Processed and saved: reduced_audio_data/179.wav
# Processed and saved: reduced_audio_data/151.wav
# Processed and saved: reduced_audio_data/145.wav
# Processed and saved: reduced_audio_data/2.wav
# Processed and saved: reduced_audio_data/50.wav
# Processed and saved: reduced_audio_data/44.wav
# Processed and saved: reduced_audio_data/192.wav
# Processed and saved: reduced_audio_data/78.wav
# Processed and saved: reduced_audio_data/186.wav
# Processed and saved: reduced_audio_data/227.wav
# Processed and saved: reduced_audio_data/233.wav
# Processed and saved: reduced_audio_data/297.wav
# Processed and saved: reduced_audio_data/283.wav
# Processed and saved: reduced_audio_data/268.wav
# Processed and saved: reduced_audio_data/254.wav
# Processed and saved: reduced_audio_data/240.wav
# Processed and saved: reduced_audio_data/23.wav
# Processed and saved: reduced_audio_data/37.wav
# Processed and saved: reduced_audio_data/122.wav
# Processed and saved: reduced_audio_data/136.wav
# Processed and saved: reduced_audio_data/308.wav
# Processed and saved: reduced_audio_data/320.wav
# Processed and saved: reduced_audio_data/334.wav
# Processed and saved: reduced_audio_data/335.wav
# Processed and saved: reduced_audio_data/321.wav
# Processed and saved: reduced_audio_data/309.wav
# Processed and saved: reduced_audio_data/137.wav
# Processed and saved: reduced_audio_data/123.wav
# Processed and saved: reduced_audio_data/36.wav
# Processed and saved: reduced_audio_data/22.wav
# Processed and saved: reduced_audio_data/241.wav
# Processed and saved: reduced_audio_data/255.wav
# Processed and saved: reduced_audio_data/269.wav
# Processed and saved: reduced_audio_data/282.wav
# Processed and saved: reduced_audio_data/296.wav
# Processed and saved: reduced_audio_data/280.wav
# Processed and saved: reduced_audio_data/294.wav
# Processed and saved: reduced_audio_data/243.wav
# Processed and saved: reduced_audio_data/257.wav
# Processed and saved: reduced_audio_data/34.wav
# Processed and saved: reduced_audio_data/20.wav
# Processed and saved: reduced_audio_data/109.wav
# Processed and saved: reduced_audio_data/135.wav
# Processed and saved: reduced_audio_data/121.wav
# Processed and saved: reduced_audio_data/337.wav
# Processed and saved: reduced_audio_data/323.wav
# Processed and saved: reduced_audio_data/322.wav
# Processed and saved: reduced_audio_data/336.wav
# Processed and saved: reduced_audio_data/120.wav
# Processed and saved: reduced_audio_data/134.wav
# Processed and saved: reduced_audio_data/108.wav
# Processed and saved: reduced_audio_data/21.wav
# Processed and saved: reduced_audio_data/35.wav
# Processed and saved: reduced_audio_data/256.wav
# Processed and saved: reduced_audio_data/242.wav
# Processed and saved: reduced_audio_data/295.wav
# Processed and saved: reduced_audio_data/281.wav
# Processed and saved: reduced_audio_data/285.wav
# Processed and saved: reduced_audio_data/291.wav
# Processed and saved: reduced_audio_data/246.wav
# Processed and saved: reduced_audio_data/252.wav
# Processed and saved: reduced_audio_data/19.wav
# Processed and saved: reduced_audio_data/31.wav
# Processed and saved: reduced_audio_data/25.wav
# Processed and saved: reduced_audio_data/130.wav
# Processed and saved: reduced_audio_data/124.wav
# Processed and saved: reduced_audio_data/118.wav
# Processed and saved: reduced_audio_data/332.wav
# Processed and saved: reduced_audio_data/326.wav
# Processed and saved: reduced_audio_data/327.wav
# Processed and saved: reduced_audio_data/333.wav
# Processed and saved: reduced_audio_data/119.wav
# Processed and saved: reduced_audio_data/125.wav
# Processed and saved: reduced_audio_data/131.wav
# Processed and saved: reduced_audio_data/24.wav
# Processed and saved: reduced_audio_data/30.wav
# Processed and saved: reduced_audio_data/18.wav
# Processed and saved: reduced_audio_data/253.wav
# Processed and saved: reduced_audio_data/247.wav
# Processed and saved: reduced_audio_data/290.wav
# Processed and saved: reduced_audio_data/284.wav
# Processed and saved: reduced_audio_data/292.wav
# Processed and saved: reduced_audio_data/286.wav
# Processed and saved: reduced_audio_data/251.wav
# Processed and saved: reduced_audio_data/245.wav
# Processed and saved: reduced_audio_data/279.wav
# Processed and saved: reduced_audio_data/26.wav
# Processed and saved: reduced_audio_data/32.wav
# Processed and saved: reduced_audio_data/127.wav
# Processed and saved: reduced_audio_data/133.wav
# Processed and saved: reduced_audio_data/325.wav
# Processed and saved: reduced_audio_data/331.wav
# Processed and saved: reduced_audio_data/319.wav
# Processed and saved: reduced_audio_data/318.wav
# Processed and saved: reduced_audio_data/330.wav
# Processed and saved: reduced_audio_data/324.wav
# Processed and saved: reduced_audio_data/132.wav
# Processed and saved: reduced_audio_data/126.wav
# Processed and saved: reduced_audio_data/33.wav
# Processed and saved: reduced_audio_data/27.wav
# Processed and saved: reduced_audio_data/278.wav
# Processed and saved: reduced_audio_data/244.wav
# Processed and saved: reduced_audio_data/250.wav
# Processed and saved: reduced_audio_data/287.wav
# Processed and saved: reduced_audio_data/293.wav

# %%
def extract_audio_features(file_path):
    """
    Extracts audio features from a given audio file.
    
    Parameters:
    - file_path (str): Path to the audio file.
    
    Returns:
    - features (dict): A dictionary containing the waveform, spectrogram, MFCCs, and chroma features.
    """
    y, sr = librosa.load(file_path, sr=None)

    # Extract waveform
    waveform = y

    # Compute spectrogram
    stft = librosa.stft(y)
    spectrogram = np.abs(stft)

    # Compute MFCCs
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

    # Compute chroma features
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)

    return {
        'waveform': waveform,
        'sample_rate': sr,
        'spectrogram': spectrogram,
        'mfccs': mfccs,
        'chroma': chroma
    }

# %%
def plot_audio_features(features):
    """
    Plots the waveform, spectrogram, MFCCs, and chroma features.

    Parameters:
    - features (dict): A dictionary containing the audio features.
    """
    waveform = features['waveform']
    sr = features['sample_rate']
    spectrogram = features['spectrogram']
    mfccs = features['mfccs']
    chroma = features['chroma']

    plt.figure(figsize=(16, 12))

    # Plot waveform
    plt.subplot(2, 2, 1)
    librosa.display.waveshow(waveform, sr=sr)
    plt.title('Waveform')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    # Plot spectrogram
    plt.subplot(2, 2, 2)
    librosa.display.specshow(librosa.amplitude_to_db(spectrogram, ref=np.max), sr=sr, x_axis='time', y_axis='log', cmap='viridis')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Spectrogram')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')

    # Plot MFCCs
    plt.subplot(2, 2, 3)
    librosa.display.specshow(mfccs, sr=sr, x_axis='time', cmap='coolwarm')
    plt.colorbar()
    plt.title('MFCCs')
    plt.xlabel('Time (s)')
    plt.ylabel('MFCC Coefficients')

    # Plot chroma features
    plt.subplot(2, 2, 4)
    librosa.display.specshow(chroma, sr=sr, x_axis='time', y_axis='chroma', cmap='coolwarm')
    plt.colorbar()
    plt.title('Chroma Features')
    plt.xlabel('Time (s)')
    plt.ylabel('Pitch Class')

    plt.tight_layout()
    plt.show()

# %%
# sample feature
file_path = 'reduced_audio_data/1.wav'
audio_features = extract_audio_features(file_path)
plot_audio_features(audio_features)

# %%
def extract_full_audio_features(file_path):
    """
    Extract various audio features from a given audio file, including duration.
    
    Parameters:
    - file_path (str): Path to the audio file.
    
    Returns:
    - dict: Dictionary containing audio features.
    """
    try:
        # Load audio file
        y, sr = librosa.load(file_path, sr=None)
        
        # Extract features
        duration = librosa.get_duration(y=y, sr=sr)
        mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13), axis=1)
        spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))
        spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=y, sr=sr))
        pitches, magnitudes = librosa.piptrack(y=y, sr=sr)
        pitch = np.mean(pitches[pitches > 0]) if pitches.any() else 0
        energy = np.sum(y**2) / len(y)
        loudness = librosa.feature.rms(y=y).mean()

        return {
            'duration': duration,
            'mfccs': mfccs.tolist(),
            'spectral_centroid': spectral_centroid,
            'spectral_bandwidth': spectral_bandwidth,
            'pitch': pitch,
            'energy': energy,
            'loudness': loudness
        }
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return {
            'duration': np.nan,
            'mfccs': [np.nan] * 13,
            'spectral_centroid': np.nan,
            'spectral_bandwidth': np.nan,
            'pitch': np.nan,
            'energy': np.nan,
            'loudness': np.nan
        }

audio_folder = 'reduced_audio_data'  # Path to folder containing audio files

# Extract features for each audio file and store in DataFrame
feature_columns = ['duration', 'mfccs', 'spectral_centroid', 'spectral_bandwidth', 'pitch', 'energy', 'loudness']
audio_features_list = []

for _, row in df.iterrows():
    file_path = os.path.join(audio_folder, f"{row['id']}.wav")
    features = extract_full_audio_features(file_path)
    features_flat = {key: val if not isinstance(val, list) else val for key, val in features.items()}
    audio_features_list.append(features_flat)

# Merge features back to the DataFrame
features_df = pd.DataFrame(audio_features_list)
# Out:
# /Users/sicilywang/anaconda3/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=384
#   warnings.warn(
# /Users/sicilywang/anaconda3/lib/python3.11/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1152
#   warnings.warn(

# %%
new_df = pd.concat([df, features_df], axis=1)

# Show the resulting DataFrame
new_df
# Out:
#            file_id  sarcasm  \
# 0            12054        0
# 1              108        0
# 2             5809        0
# 3              145        0
# 4             4227        0
# ..             ...      ...
# 424  sar_sicily_23        0
# 425  sar_sicily_46        0
# 426      evelyn_15        0
# 427          21635        0
# 428          12675        0
#
#                                                   text  label   emotion   id  \
# 0     Didn't have to tell you that Somebody's a Jan...      0     anger    1
# 1                         already respects the bucket.      0     anger    2
# 2     I accept all those flaws, why can't you accep...      0     anger    3
# 3                This is my wife Nancy. Look, get out!      0     anger    4
# 4     Fine! Then you tell Roger because he was real...      0     anger    5
# ..                                                 ...    ...       ...  ...
# 424                       What happened to my parlour?      0  surprise  425
# 425   What? My car! It's gone! But... but... but......      0  surprise  426
# 426   Ugh, what's going on? I mean, what are you do...      0  surprise  427
# 427                    how can you not know which one?      0  surprise  428
# 428  whoa it's huge. So much ... in the cubical. Th...      1  surprise  429
#
#       duration                                              mfccs  \
# 0     5.240000  [-581.4388427734375, 103.19503021240234, -34.1...
# 1     1.399977  [-519.671630859375, 99.21368408203125, -31.404...
# 2     3.320000  [-604.3026733398438, 90.88034057617188, -34.52...
# 3     3.860000  [-593.0642700195312, 92.73889923095703, -22.86...
# 4     3.780000  [-523.6166381835938, 77.15715789794922, -10.64...
# ..         ...                                                ...
# 424   2.200000  [-495.8974609375, 105.8569107055664, -15.63068...
# 425   5.610667  [-684.0684204101562, 48.05113220214844, -13.70...
# 426  10.752000  [-690.7086181640625, 63.86827087402344, -7.107...
# 427   1.550000  [-514.0931396484375, 126.76039123535156, -32.4...
# 428   8.199977  [-666.9378662109375, 90.53575134277344, -11.14...
#
#      spectral_centroid  spectral_bandwidth        pitch    energy  loudness  \
# 0          3194.061155         2498.073258  1724.758789  0.000169  0.009737
# 1          3207.430827         2460.578687  1596.321533  0.000481  0.017747
# 2          3189.165736         2348.431343  2021.348999  0.000165  0.009494
# 3          4078.493479         3491.345131  1616.683838  0.000181  0.008689
# 4          3678.133007         2459.192276  1724.678101  0.001107  0.024616
# ..                 ...                 ...          ...       ...       ...
# 424        3144.974111         2841.541063  1395.852905  0.000807  0.021128
# 425        5777.586640         4555.686200  1681.129272  0.000048  0.003806
# 426        4286.795750         3675.188011  1928.205444  0.000047  0.004524
# 427        2472.252426         2386.249516  1754.947632  0.000246  0.012379
# 428        3235.470431         2565.076934  1635.679810  0.000055  0.005395
#
#       duration                                              mfccs  \
# 0     5.240000  [-581.4388427734375, 103.19503021240234, -34.1...
# 1     1.399977  [-519.671630859375, 99.21368408203125, -31.404...
# 2     3.320000  [-604.3026733398438, 90.88034057617188, -34.52...
# 3     3.860000  [-593.0642700195312, 92.73889923095703, -22.86...
# 4     3.780000  [-523.6166381835938, 77.15715789794922, -10.64...
# ..         ...                                                ...
# 424   2.200000  [-495.8974609375, 105.8569107055664, -15.63068...
# 425   5.610667  [-684.0684204101562, 48.05113220214844, -13.70...
# 426  10.752000  [-690.7086181640625, 63.86827087402344, -7.107...
# 427   1.550000  [-514.0931396484375, 126.76039123535156, -32.4...
# 428   8.199977  [-666.9378662109375, 90.53575134277344, -11.14...
#
#      spectral_centroid  spectral_bandwidth        pitch    energy  loudness
# 0          3194.061155         2498.073258  1724.758789  0.000169  0.009737
# 1          3207.430827         2460.578687  1596.321533  0.000481  0.017747
# 2          3189.165736         2348.431343  2021.348999  0.000165  0.009494
# 3          4078.493479         3491.345131  1616.683838  0.000181  0.008689
# 4          3678.133007         2459.192276  1724.678101  0.001107  0.024616
# ..                 ...                 ...          ...       ...       ...
# 424        3144.974111         2841.541063  1395.852905  0.000807  0.021128
# 425        5777.586640         4555.686200  1681.129272  0.000048  0.003806
# 426        4286.795750         3675.188011  1928.205444  0.000047  0.004524
# 427        2472.252426         2386.249516  1754.947632  0.000246  0.012379
# 428        3235.470431         2565.076934  1635.679810  0.000055  0.005395
#
# [429 rows x 20 columns]

# %%
columns_to_plot = ['spectral_centroid', 'spectral_bandwidth', 'pitch', 'energy', 'loudness']

# Plot box plots for each feature
for col in columns_to_plot:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=new_df, x='emotion', y=col, palette='Set2')
    plt.title(f'Distribution of {col} by Sarcasm')
    plt.xlabel('Sarcasm')
    plt.ylabel(col.capitalize())
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2d/qjytj_ws79lcn297bxnmlmx00000gn/T/ipykernel_11962/4046813355.py in ?()
#       2
#       3 # Plot box plots for each feature
#       4 for col in columns_to_plot:
#       5     plt.figure(figsize=(10, 6))
# ----> 6     sns.boxplot(data=new_df, x='emotion', y=col, palette='Set2')
#       7     plt.title(f'Distribution of {col} by Sarcasm')
#       8     plt.xlabel('Sarcasm')
#       9     plt.ylabel(col.capitalize())
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
#    2230
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
#    2233                           width, dodge, fliersize, linewidth)
#    2234
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     781     def __init__(self, x, y, hue, data, order, hue_order,
#     782                  orient, color, palette, saturation,
#     783                  width, dodge, fliersize, linewidth):
#     784
# --> 785         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     786         self.establish_colors(color, palette, saturation)
#     787
#     788         self.dodge = dodge
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, orient, order, hue_order, units)
#     540                     err = f"Could not interpret input '{var}'"
#     541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
# --> 544             orient = infer_orient(
#     545                 x, y, orient, require_numeric=self.require_numeric
#     546             )
#     547
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py in ?(x, y, orient, require_numeric)
#    1581
#    1582     """
#    1583
#    1584     x_type = None if x is None else variable_type(x)
# -> 1585     y_type = None if y is None else variable_type(y)
#    1586
#    1587     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#    1588     single_var_warning = "{} orientation ignored with only `{}` specified."
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py in ?(vector, boolean_type)
#    1498     if pd.api.types.is_categorical_dtype(vector):
#    1499         return VariableType("categorical")
#    1500
#    1501     # Special-case all-na data, which is always "numeric"
# -> 1502     if pd.isna(vector).all():
#    1503         return VariableType("numeric")
#    1504
#    1505     # Special-case binary/boolean data, allow caller to determine
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1525     @final
#    1526     def __nonzero__(self) -> NoReturn:
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
def extract_mean_features(file_path):
    """
    Extract mean audio features from a given audio file for EDA.
    
    Returns a dictionary of mean features for statistical comparison.
    """
    y, sr = librosa.load(file_path, sr=None)
    
    # Compute features
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)

    return {
        'mean_mfccs': np.mean(mfccs, axis=1),
        'mean_chroma': np.mean(chroma, axis=1),
        'mean_spectral_centroid': np.mean(spectral_centroid)
    }

# Initialize DataFrame to store features
eda_features = []

audio_folder = 'reduced_audio_data'  # Folder containing audio files

# Extract mean features for each emotion
for _, row in df.iterrows():
    file_path = os.path.join(audio_folder, f"{row['id']}.wav")
    if os.path.exists(file_path):
        features = extract_mean_features(file_path)
        eda_features.append({
            'emotion': row['emotion'],
            **{f'mfcc_{i+1}': mfcc for i, mfcc in enumerate(features['mean_mfccs'])},
            **{f'chroma_{i+1}': chroma for i, chroma in enumerate(features['mean_chroma'])},
            'spectral_centroid': features['mean_spectral_centroid']
        })

eda_df = pd.DataFrame(eda_features)

# Boxplot for MFCCs
plt.figure(figsize=(14, 8))
sns.boxplot(data=eda_df.melt(id_vars='emotion', value_vars=[f'mfcc_{i+1}' for i in range(13)]), 
            x='variable', y='value', hue='emotion')
plt.title('MFCCs Distribution by Emotion')
plt.xlabel('MFCC Coefficients')
plt.ylabel('Value')
plt.legend(title='Emotion')
plt.show()

# Boxplot for Chroma Features
plt.figure(figsize=(14, 8))
sns.boxplot(data=eda_df.melt(id_vars='emotion', value_vars=[f'chroma_{i+1}' for i in range(12)]), 
            x='variable', y='value', hue='emotion')
plt.title('Chroma Features Distribution by Emotion')
plt.xlabel('Chroma Pitch Class')
plt.ylabel('Value')
plt.legend(title='Emotion')
plt.show()

# Violin Plot for Spectral Centroid
plt.figure(figsize=(10, 6))
sns.violinplot(data=eda_df, x='emotion', y='spectral_centroid')
plt.title('Spectral Centroid Distribution by Emotion')
plt.xlabel('Emotion')
plt.ylabel('Mean Spectral Centroid')
plt.show()
# Out:
# /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=384
#   warnings.warn(
# /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /Users/vivianzhao/anaconda3/envs/dsc80/lib/python3.8/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1152
#   warnings.warn(

# %% [markdown]
# # Text Feature Extraction
